# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab.patches import cv2_imshow

# %%
import os
os.chdir('/content/drive/MyDrive/Python')

# %%
img = cv2.imread('itpln.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=819x300 at 0x7FEFB02EF410>

# %%
cv2_imshow(img)
cv2_imshow(img[:,:,0])
cv2_imshow(img[:,:,1])
cv2_imshow(img[:,:,2])
# Out:
# <PIL.Image.Image image mode=RGB size=819x300 at 0x7FEFAFA82990>
# <PIL.Image.Image image mode=L size=819x300 at 0x7FEFAFA82910>
# <PIL.Image.Image image mode=L size=819x300 at 0x7FEFAFA82D10>
# <PIL.Image.Image image mode=L size=819x300 at 0x7FEFAFA82C90>

# %%
print (img.size)
# Out:
# 737100

# %%
print (img.shape)
# Out:
# (300, 819, 3)

# %%
print (img.dtype)
# Out:
# uint8

# %%
b = img[:,:,0]
g = img[:,:,1]
r = img[:,:,2]

# %%
import numpy as np

panjang = len(img)
lebar = len(img[0])

img_gray = np.zeros((panjang,lebar))

for i in range(panjang) :
  for j in range(lebar) :
    img_gray[i,j] = 0.2989*r[i,j]+0.587*g[i,j]+0.1141*b[i,j]

img_gray = img_gray.astype(np.uint8)

#khusus colab
cv2_imshow(img_gray)

#khusus jupyter
#cv2.imshow("biner_image", img_gray)
#cv2.waitKey()
#cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=819x300 at 0x7FEFA50CCD50>

# %%
img2 = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=L size=819x300 at 0x7F18917553D0>

# %%
img2 = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=819x300 at 0x7F1890E900D0>

# %%
b,g,r = cv2.split(img)

# %%
cv2_imshow(b)
# Out:
# <PIL.Image.Image image mode=L size=819x300 at 0x7F18864F6C10>

# %%
cv2_imshow(g)
# Out:
# <PIL.Image.Image image mode=L size=819x300 at 0x7F18864B8210>

# %%
cv2_imshow(r)
# Out:
# <PIL.Image.Image image mode=L size=819x300 at 0x7F18864D5710>

# %%
print(img)
# Out:
# [[[ 58  52  47]
#   [ 58  52  47]
#   [ 58  52  47]
#   ...
#   [202 191 183]
#   [202 191 183]
#   [202 191 183]]
#
#  [[ 58  52  47]
#   [ 58  52  47]
#   [ 58  52  47]
#   ...
#   [203 192 184]
#   [203 192 184]
#   [203 192 184]]
#
#  [[ 58  52  47]
#   [ 58  52  47]
#   [ 58  52  47]
#   ...
#   [203 192 184]
#   [203 192 184]
#   [203 192 184]]
#
#  ...
#
#  [[  8  18  12]
#   [ 11  21  15]
#   [ 14  26  20]
#   ...
#   [ 11  19  12]
#   [ 14  22  15]
#   [ 18  26  19]]
#
#  [[  5  15   9]
#   [  6  16  10]
#   [  8  20  14]
#   ...
#   [  7  15   8]
#   [  8  16   9]
#   [ 12  20  13]]
#
#  [[  9  19  13]
#   [  8  18  12]
#   [  6  18  12]
#   ...
#   [  7  15   8]
#   [  6  14   7]
#   [ 10  18  11]]]
